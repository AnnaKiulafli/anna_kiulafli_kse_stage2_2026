# %% [markdown]
# # Nationwide Ukrainian air-raid alert EDA
# This notebook is a reproducible companion to `scripts/run_eda.py`; both use the same processed inputs and core EDA functions. Run the script to regenerate all tables, figures, and the summary report.

# %%
from pathlib import Path
script = Path('scripts/run_eda.py')
if not script.exists():
    script = Path('..') / 'scripts' / 'run_eda.py'
# %run $script

# %% [markdown]
# See `reports/eda/eda_summary.md`, `reports/eda/tables/`, and `reports/eda/figures/` for generated outputs.
